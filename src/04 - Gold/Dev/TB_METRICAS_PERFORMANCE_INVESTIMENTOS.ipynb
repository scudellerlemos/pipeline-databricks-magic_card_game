# %%
# ============================================================================
# Camada Gold - Métricas Performance Investimentos - Magic: The Gathering
# Transformação de negócio em SQL (spark.sql sobre temp views)
# ============================================================================

# ============================================================================
# BIBLIOTECAS UTILIZADAS
# ============================================================================
import logging

# ============================================================================
# IMPORTAÇÃO DO MÓDULO UTILITÁRIO
# ============================================================================
# %run "../../00 - Common/Dev/base_utils"
# %run ./gold_utils

# ============================================================================
# CONFIGURAÇÃO COM MÓDULO UTILITÁRIO
# ============================================================================
TABLE_NAME = "TB_METRICAS_PERFORMANCE_INVESTIMENTOS"

# Inicializar processador com configuração manual
config = create_manual_config(
    catalog_name="magic_the_gathering",
    s3_bucket=get_secret("s3_bucket"),
    s3_gold_prefix="magic_the_gathering/gold"
)
processor = GoldTableProcessor(TABLE_NAME, config)
spark = processor.spark

# %%
# ============================================================================
# CARREGAMENTO DE DADOS SILVER COM MÓDULO
# ============================================================================
dfs = processor.load_silver_data(['cards'])
dfs['cards'].createOrReplaceTempView("cards")

# ============================================================================
# JOIN PRINCIPAL
# ============================================================================
# Preço já vem anexado por nome direto na TB_FATO_SILVER_CARDS (Silver unificou
# cards+prices - ver TB_FATO_SILVER_CARDS.ipynb/attach_prices), então não há
# mais join aqui. DT_PRICE_INGESTION (não DT_INGESTION de cards, que é fixo -
# sempre a última leitura do catálogo) é o que varia dia a dia e sustenta as
# janelas de lag/volatilidade abaixo; mantido com o alias DT_INGESTION para
# não alterar o restante do notebook. WHERE exclui cartas sem preço
# encontrado (mesma semântica do INNER JOIN anterior).
spark.sql("""
    CREATE OR REPLACE TEMP VIEW _perf_join AS
    SELECT
        cards.ID_CARD AS ID_CARD,
        cards.NME_CARD AS NME_CARD,
        cards.COD_SET AS COD_SET,
        cards.NME_SET AS NME_SET,
        cards.NME_CARD_TYPE AS NME_CARD_TYPE,
        cards.NME_RARITY AS NME_RARITY,
        cards.NME_ARTIST AS NME_ARTIST,
        cards.VLR_USD AS VLR_USD,
        cards.DT_PRICE_INGESTION AS DT_INGESTION
    FROM cards
    WHERE cards.DT_PRICE_INGESTION IS NOT NULL
""")

# %%
# ============================================================================
# FILTRAR DADOS COM HISTÓRICO SUFICIENTE
# ============================================================================
spark.sql("""
    CREATE OR REPLACE TEMP VIEW _perf_filtrado AS
    SELECT *
    FROM (
        SELECT *, count(*) OVER (PARTITION BY ID_CARD) AS QTD_REGISTROS_CARTA
        FROM _perf_join
    )
    WHERE QTD_REGISTROS_CARTA >= 30
""")

# ============================================================================
# CÁLCULOS DE PERFORMANCE POR PERÍODO (7/30/90/365 dias)
# ============================================================================
# Partition por ID_CARD (grão por impressão) em vez de NME_CARD+COD_SET:
# variantes de arte da mesma coleção têm séries de preço independentes (AUD-10)

# Preços defasados (lag) e volatilidade (stddev na janela) por período, e
# preço máximo histórico acumulado - todos independentes entre si, calculados
# em um único estágio
spark.sql("""
    CREATE OR REPLACE TEMP VIEW _perf_lags AS
    SELECT
        *,
        lag(VLR_USD, 7)   OVER (PARTITION BY ID_CARD ORDER BY DT_INGESTION) AS VLR_USD_7D_ANTES,
        lag(VLR_USD, 30)  OVER (PARTITION BY ID_CARD ORDER BY DT_INGESTION) AS VLR_USD_30D_ANTES,
        lag(VLR_USD, 90)  OVER (PARTITION BY ID_CARD ORDER BY DT_INGESTION) AS VLR_USD_90D_ANTES,
        lag(VLR_USD, 365) OVER (PARTITION BY ID_CARD ORDER BY DT_INGESTION) AS VLR_USD_365D_ANTES,
        cast(stddev(VLR_USD) OVER (PARTITION BY ID_CARD ORDER BY DT_INGESTION ROWS BETWEEN 7 PRECEDING AND CURRENT ROW) AS FLOAT) AS VOLATILIDADE_7D,
        cast(stddev(VLR_USD) OVER (PARTITION BY ID_CARD ORDER BY DT_INGESTION ROWS BETWEEN 30 PRECEDING AND CURRENT ROW) AS FLOAT) AS VOLATILIDADE_30D,
        cast(stddev(VLR_USD) OVER (PARTITION BY ID_CARD ORDER BY DT_INGESTION ROWS BETWEEN 90 PRECEDING AND CURRENT ROW) AS FLOAT) AS VOLATILIDADE_90D,
        cast(stddev(VLR_USD) OVER (PARTITION BY ID_CARD ORDER BY DT_INGESTION ROWS BETWEEN 365 PRECEDING AND CURRENT ROW) AS FLOAT) AS VOLATILIDADE_365D,
        max(VLR_USD) OVER (PARTITION BY ID_CARD ORDER BY DT_INGESTION ROWS BETWEEN UNBOUNDED PRECEDING AND CURRENT ROW) AS PRECO_MAXIMO_HISTORICO
    FROM _perf_filtrado
""")

# Retorno percentual por período (a partir dos preços defasados) e drawdown
# atual (queda em relação ao preço máximo histórico)
spark.sql("""
    CREATE OR REPLACE TEMP VIEW _perf_retorno AS
    SELECT
        *,
        CASE WHEN VLR_USD_7D_ANTES IS NOT NULL AND VLR_USD_7D_ANTES != 0
             THEN cast((VLR_USD - VLR_USD_7D_ANTES) / VLR_USD_7D_ANTES AS FLOAT) ELSE NULL END AS RETORNO_7D,
        CASE WHEN VLR_USD_30D_ANTES IS NOT NULL AND VLR_USD_30D_ANTES != 0
             THEN cast((VLR_USD - VLR_USD_30D_ANTES) / VLR_USD_30D_ANTES AS FLOAT) ELSE NULL END AS RETORNO_30D,
        CASE WHEN VLR_USD_90D_ANTES IS NOT NULL AND VLR_USD_90D_ANTES != 0
             THEN cast((VLR_USD - VLR_USD_90D_ANTES) / VLR_USD_90D_ANTES AS FLOAT) ELSE NULL END AS RETORNO_90D,
        CASE WHEN VLR_USD_365D_ANTES IS NOT NULL AND VLR_USD_365D_ANTES != 0
             THEN cast((VLR_USD - VLR_USD_365D_ANTES) / VLR_USD_365D_ANTES AS FLOAT) ELSE NULL END AS RETORNO_365D,
        CASE WHEN PRECO_MAXIMO_HISTORICO IS NOT NULL AND PRECO_MAXIMO_HISTORICO != 0
             THEN cast((VLR_USD - PRECO_MAXIMO_HISTORICO) / PRECO_MAXIMO_HISTORICO AS FLOAT) ELSE NULL END AS DRAWDOWN_ATUAL
    FROM _perf_lags
""")

# Sharpe Ratio por período (retorno ajustado ao risco, taxa livre de risco de
# 2% a.a. rateada ao dia) e maior drawdown nos últimos 90 dias
spark.sql("""
    CREATE OR REPLACE TEMP VIEW _perf_sharpe AS
    SELECT
        *,
        CASE WHEN VOLATILIDADE_7D IS NOT NULL AND VOLATILIDADE_7D != 0
             THEN cast((RETORNO_7D - (0.02 / 365)) / VOLATILIDADE_7D AS FLOAT) ELSE NULL END AS SHARPE_RATIO_7D,
        CASE WHEN VOLATILIDADE_30D IS NOT NULL AND VOLATILIDADE_30D != 0
             THEN cast((RETORNO_30D - (0.02 / 365)) / VOLATILIDADE_30D AS FLOAT) ELSE NULL END AS SHARPE_RATIO_30D,
        CASE WHEN VOLATILIDADE_90D IS NOT NULL AND VOLATILIDADE_90D != 0
             THEN cast((RETORNO_90D - (0.02 / 365)) / VOLATILIDADE_90D AS FLOAT) ELSE NULL END AS SHARPE_RATIO_90D,
        CASE WHEN VOLATILIDADE_365D IS NOT NULL AND VOLATILIDADE_365D != 0
             THEN cast((RETORNO_365D - (0.02 / 365)) / VOLATILIDADE_365D AS FLOAT) ELSE NULL END AS SHARPE_RATIO_365D,
        cast(min(DRAWDOWN_ATUAL) OVER (PARTITION BY ID_CARD ORDER BY DT_INGESTION ROWS BETWEEN 90 PRECEDING AND CURRENT ROW) AS FLOAT) AS MAX_DRAWDOWN_90D
    FROM _perf_retorno
""")

# ============================================================================
# CLASSIFICAÇÃO DE RISCO E SCORING
# ============================================================================
spark.sql("""
    CREATE OR REPLACE TEMP VIEW _perf_scoring AS
    SELECT
        *,
        CASE WHEN VOLATILIDADE_30D < 0.1 THEN 'Conservador'
             WHEN VOLATILIDADE_30D < 0.2 THEN 'Moderado'
             ELSE 'Agressivo' END AS PERFIL_RISCO,
        CASE WHEN RETORNO_30D IS NOT NULL
             THEN greatest(least(RETORNO_30D * 100 + 50, 100), 0)
             ELSE 50 END AS SCORE_RETORNO_30D,
        CASE WHEN SHARPE_RATIO_30D IS NOT NULL
             THEN greatest(least(SHARPE_RATIO_30D * 20 + 50, 100), 0)
             ELSE 50 END AS SCORE_SHARPE_30D,
        CASE WHEN MAX_DRAWDOWN_90D IS NOT NULL
             THEN greatest(least(-MAX_DRAWDOWN_90D * 100 + 50, 100), 0)
             ELSE 50 END AS SCORE_DRAWDOWN
    FROM _perf_sharpe
""")

# Investment Score final (0-100)
spark.sql("""
    CREATE OR REPLACE TEMP VIEW _perf_final AS
    SELECT
        *,
        round(SCORE_RETORNO_30D * 0.4 + SCORE_SHARPE_30D * 0.3 + SCORE_DRAWDOWN * 0.3, 2) AS INVESTMENT_SCORE
    FROM _perf_scoring
""")

# %%
# ============================================================================
# AGREGAÇÃO FINAL POR CARTA
# ============================================================================
# last() sem janela em GROUP BY não tem ordem garantida (shuffle) - troca por
# row_number() particionado/ordenado por DT_INGESTION para pegar a linha mais
# recente de forma determinística; agregados de fato (media/contagem) ficam
# em uma segunda view e são juntados de volta.
spark.sql("""
    CREATE OR REPLACE TEMP VIEW _perf_latest AS
    SELECT *
    FROM (
        SELECT *, row_number() OVER (PARTITION BY ID_CARD ORDER BY DT_INGESTION DESC) AS _rn_latest
        FROM _perf_final
    )
    WHERE _rn_latest = 1
""")

spark.sql("""
    CREATE OR REPLACE TEMP VIEW _perf_historico AS
    SELECT
        ID_CARD,
        cast(avg(VLR_USD) AS FLOAT) AS PRECO_MEDIO_HISTORICO,
        cast(count(*) AS INT) AS QTD_DIAS_HISTORICO
    FROM _perf_final
    GROUP BY ID_CARD
""")

df_final = spark.sql("""
    SELECT
        l.ID_CARD, l.NME_CARD, l.COD_SET, l.NME_SET, l.NME_CARD_TYPE, l.NME_RARITY, l.NME_ARTIST,
        l.DT_INGESTION AS DT_ULTIMA_ATUALIZACAO,
        cast(l.VLR_USD AS FLOAT) AS PRECO_ATUAL,
        cast(l.PRECO_MAXIMO_HISTORICO AS FLOAT) AS PRECO_MAXIMO_HISTORICO,

        cast(l.RETORNO_7D AS FLOAT) AS RETORNO_7D,
        cast(l.RETORNO_30D AS FLOAT) AS RETORNO_30D,
        cast(l.RETORNO_90D AS FLOAT) AS RETORNO_90D,
        cast(l.RETORNO_365D AS FLOAT) AS RETORNO_365D,

        cast(l.VOLATILIDADE_7D AS FLOAT) AS VOLATILIDADE_7D,
        cast(l.VOLATILIDADE_30D AS FLOAT) AS VOLATILIDADE_30D,
        cast(l.VOLATILIDADE_90D AS FLOAT) AS VOLATILIDADE_90D,
        cast(l.VOLATILIDADE_365D AS FLOAT) AS VOLATILIDADE_365D,

        cast(l.SHARPE_RATIO_7D AS FLOAT) AS SHARPE_RATIO_7D,
        cast(l.SHARPE_RATIO_30D AS FLOAT) AS SHARPE_RATIO_30D,
        cast(l.SHARPE_RATIO_90D AS FLOAT) AS SHARPE_RATIO_90D,
        cast(l.SHARPE_RATIO_365D AS FLOAT) AS SHARPE_RATIO_365D,

        cast(l.MAX_DRAWDOWN_90D AS FLOAT) AS MAX_DRAWDOWN_90D,
        l.PERFIL_RISCO AS PERFIL_RISCO,
        cast(l.INVESTMENT_SCORE AS FLOAT) AS INVESTMENT_SCORE,

        h.PRECO_MEDIO_HISTORICO,
        h.QTD_DIAS_HISTORICO
    FROM _perf_latest l
    JOIN _perf_historico h ON l.ID_CARD = h.ID_CARD
""")

# ============================================================================
# ADICIONAR DATA DE REFERÊNCIA E RANKINGS
# ============================================================================
# tie-break por hash(ID_CARD): ID_CARD já é chave única desta tabela (uma
# linha por carta, pós-dedup em _perf_latest), então hash dela sozinha basta
# pra desempatar ORDER BY de forma determinística (mesmo padrão da AUD-19,
# sem precisar hashear várias colunas por não haver linhas duplicadas aqui).
df_final.createOrReplaceTempView("_perf_agregado")
df_final = spark.sql("""
    SELECT
        *,
        current_date() AS DATA_REF,
        cast(row_number() OVER (ORDER BY RETORNO_30D DESC, hash(ID_CARD) DESC) AS INT) AS RANK_RETORNO_30D,
        cast(row_number() OVER (ORDER BY SHARPE_RATIO_30D DESC, hash(ID_CARD) DESC) AS INT) AS RANK_SHARPE_30D,
        cast(row_number() OVER (ORDER BY INVESTMENT_SCORE DESC, hash(ID_CARD) DESC) AS INT) AS RANK_INVESTMENT_SCORE
    FROM _perf_agregado
""")

# ============================================================================
# ESCRITA DA TABELA COM MÓDULO
# ============================================================================
processor.save_gold_table(df_final, partition_cols=["NME_SET"])

# ============================================================================
# FINALIZAÇÃO
# ============================================================================
print("TB_METRICAS_PERFORMANCE_INVESTIMENTOS criada com sucesso!")
